# %%
import pandas as pd

# %%
vehicle_df = pd.read_csv("C:\\Users\\Mahvish Fatima\\Documents\\BTPS\\vehicle_price.csv")
vehicle_df.head()
# Out:
#                               name  \
# 0     2024 Jeep Wagoneer Series II
# 1  2024 Jeep Grand Cherokee Laredo
# 2         2024 GMC Yukon XL Denali
# 3       2023 Dodge Durango Pursuit
# 4            2024 RAM 3500 Laramie
#
#                                          description   make           model  \
# 0  \n      \n        Heated Leather Seats, Nav Sy...   Jeep        Wagoneer
# 1  Al West is committed to offering every custome...   Jeep  Grand Cherokee
# 2                                                NaN    GMC        Yukon XL
# 3  White Knuckle Clearcoat 2023 Dodge Durango Pur...  Dodge         Durango
# 4  \n      \n        2024 Ram 3500 Laramie Billet...    RAM            3500
#
#    year    price                                             engine  \
# 0  2024  74600.0                            24V GDI DOHC Twin Turbo
# 1  2024  50170.0                                                OHV
# 2  2024  96410.0  6.2L V-8 gasoline direct injection, variable v...
# ...

# %%
vehicle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1002 non-null   object
#  1   description     946 non-null    object
#  2   make            1002 non-null   object
#  3   model           1002 non-null   object
#  4   year            1002 non-null   int64
#  5   price           979 non-null    float64
#  6   engine          1000 non-null   object
#  7   cylinders       897 non-null    float64
#  8   fuel            995 non-null    object
#  9   mileage         968 non-null    float64
#  10  transmission    1000 non-null   object
#  11  trim            1001 non-null   object
#  12  body            999 non-null    object
#  13  doors           995 non-null    float64
#  14  exterior_color  997 non-null    object
#  15  interior_color  964 non-null    object
#  16  drivetrain      1002 non-null   object
# ...

# %%
vehicle_df.drop(['make', 'model', 'year', 'trim'], axis=1, inplace=True)

# %%
vehicle_df
# Out:
#                                                 name  \
# 0                       2024 Jeep Wagoneer Series II
# 1                    2024 Jeep Grand Cherokee Laredo
# 2                           2024 GMC Yukon XL Denali
# 3                         2023 Dodge Durango Pursuit
# 4                              2024 RAM 3500 Laramie
# ...                                              ...
# 997   2024 Mercedes-Benz Sprinter 2500 Standard Roof
# 998           2024 Dodge Hornet Hornet R/T Plus Eawd
# 999                          2024 Jeep Wagoneer Base
# 1000           2024 Nissan Murano SV Intelligent AWD
# 1001                2024 Chevrolet Silverado 2500 WT
#
#                                             description    price  \
# 0     \n      \n        Heated Leather Seats, Nav Sy...  74600.0
# 1     Al West is committed to offering every custome...  50170.0
# 2                                                   NaN  96410.0
# ...

# %%
vehicle_df.boxplot()
# Out:
# <Axes: >

# %%
vehicle_df.columns
# Out:
# Index(['name', 'description', 'price', 'engine', 'cylinders', 'fuel',
#        'mileage', 'transmission', 'body', 'doors', 'exterior_color',
#        'interior_color', 'drivetrain'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# %%
for column in vehicle_df.columns:
    if vehicle_df[column].dtype == 'object':
        vehicle_df[column] = label_encoder.fit_transform(vehicle_df[column])
        # print(column)

# %%
vehicle_df.head()
# Out:
#    name  description    price  engine  cylinders  fuel  mileage  transmission  \
# 0   231          238  74600.0      23        6.0     4     10.0            19
# 1   223          577  50170.0      66        6.0     4      1.0            19
# 2   159          761  96410.0      48        8.0     4      0.0            32
# 3     7          750  46835.0      13        8.0     4     32.0            19
# 4   314           68  81663.0      19        6.0     0     10.0             9
#
#    body  doors  exterior_color  interior_color  drivetrain
# 0     6    4.0             257              35           1
# 1     6    4.0             144              35           1
# 2     6    4.0             236              82           1
# 3     6    4.0             259               5           0
# 4     5    4.0             207               5           1

# %%
vehicle_df.isna().sum()
# Out:
# name                0
# description         0
# price              23
# engine              0
# cylinders         105
# fuel                0
# mileage            34
# transmission        0
# body                0
# doors               7
# exterior_color      0
# interior_color      0
# drivetrain          0
# dtype: int64

# %%
vehicle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            1002 non-null   int32
#  1   description     1002 non-null   int32
#  2   price           979 non-null    float64
#  3   engine          1002 non-null   int32
#  4   cylinders       897 non-null    float64
#  5   fuel            1002 non-null   int32
#  6   mileage         968 non-null    float64
#  7   transmission    1002 non-null   int32
#  8   body            1002 non-null   int32
#  9   doors           995 non-null    float64
#  10  exterior_color  1002 non-null   int32
#  11  interior_color  1002 non-null   int32
#  12  drivetrain      1002 non-null   int32
# dtypes: float64(4), int32(9)
# memory usage: 66.7 KB

# %%
vehicle_df.dropna(inplace=True)

# %%
vehicle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 841 entries, 0 to 1001
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            841 non-null    int32
#  1   description     841 non-null    int32
#  2   price           841 non-null    float64
#  3   engine          841 non-null    int32
#  4   cylinders       841 non-null    float64
#  5   fuel            841 non-null    int32
#  6   mileage         841 non-null    float64
#  7   transmission    841 non-null    int32
#  8   body            841 non-null    int32
#  9   doors           841 non-null    float64
#  10  exterior_color  841 non-null    int32
#  11  interior_color  841 non-null    int32
#  12  drivetrain      841 non-null    int32
# dtypes: float64(4), int32(9)
# memory usage: 62.4 KB

# %% [markdown]
# ### np.mean(np.array([1,12,23,34,45]))

# %%
X = vehicle_df.drop('price', axis=1)

# %%
y = vehicle_df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=48)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_regression = LinearRegression()

# %%
linear_regression.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = linear_regression.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
print(f'r2_score = {r2_score(y_test, y_pred)}')
print(f'mae = {mean_absolute_error(y_test, y_pred)}')
print(f'mae = {mean_squared_error(y_test, y_pred)}')
# Out:
# r2_score = 0.4157682680724256
# mae = 10066.169406379593
# mae = 155785205.85963616
